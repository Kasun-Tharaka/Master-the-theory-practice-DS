# %%
fruits = ['apple', 'banana', 'cherry', 'orange', 'grape', 'kiwi']

# %%
print(fruits[2])
# Out:
# cherry

# %%
print(fruits[-1])
# Out:
# kiwi

# %%
print(fruits[2:])
# Out:
# ['cherry', 'orange', 'grape', 'kiwi']

# %%
print(fruits[:3])
# Out:
# ['apple', 'banana', 'cherry']

# %%
print(fruits[2:4])
# Out:
# ['cherry', 'orange']

# %%
print(fruits[-1:-4:-1])
# Out:
# ['kiwi', 'grape', 'orange']

# %%
print(fruits[::-1])
# Out:
# ['kiwi', 'grape', 'orange', 'cherry', 'banana', 'apple']
