# %%
resul= int(input('Enter your result: '))

# %%
print("The result of the exam is: ", resul)
# Out:
# The result of the exam is:  87

# %%
a = 17
b = 7

floor_devition = a // b
modular_divition = a % b
exponentioal = a ** b

print("floor_devition", floor_devition)
print("modular_divition", modular_divition)
print("Expomentioal", exponentioal)
# Out:
# floor_devition 2
# modular_divition 3
# Expomentioal 410338673

# %%
print(f"Floor {type(floor_devition)}, \nModular {type(modular_divition)}, \nExponential {type(exponentioal)}")
# Out:
# Floor <class 'int'>,
# Modular <class 'int'>,
# Exponential <class 'int'>

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a > b
# Out:
# True

# %%
a >= b
# Out:
# True

# %%
X = True
Y = True

print(X and Y)
# Out:
# True

# %%
e = True
f = False
g = True
h = False

print(e or f)
print(f or h)
# Out:
# True
# False

# %%
# inverse operation

print(not e)
print(not f)
# Out:
# False
# True
