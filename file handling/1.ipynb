# %%
# Read a Whole File

with open('example.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Hello Kasun
# Welcome to the Full Stack Data Science Practice

# %%
# Read a file line by line
