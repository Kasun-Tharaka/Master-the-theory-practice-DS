# %%
# Read a Whole File

with open('example.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# this is first line
# this is second line
# this is third line
# Data Science is the best

# %%
# Read a file line by line
with open('example.txt', 'r') as file:
    for line in file:
        print(line.strip())
# Out:
# this is first line
# this is second line
# this is third line
# Data Science is the best

# %%
# this code overwrite the file completely
with open('example.txt', 'w') as file:
    file.write('this is new to file line')

# %%
with open('example.txt', 'a') as file:
    file.write('\nthis is appended line to the file')

# %%
with open('example.txt', 'r') as file:
    for i in file:
        print(i.strip())
# Out:
# this is new to file line
# this is appended line to the file

# %%
lines = ['this is first line\n', 'this is second line\n', 'this is third line\n', 'Data Science is the best\n']
with open('example.txt', 'a') as file:
    file.writelines(lines)

# %%
with open('example.txt', 'r') as file:
    # content = file.read()
    # print(content)

    for i in file:
        print(i.strip())
# Out:
# this is new to file line
# this is appended line to the filethis is first line
# this is second line
# this is third line
# Data Science is the best
